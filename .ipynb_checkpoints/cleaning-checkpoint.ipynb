# %%
import pandas as pd
characters = pd.read_csv("data/character-predictions_pose.csv")
battles = pd.read_csv("data/battles.csv")

# %%
characters.head()
# Out:
#    S.No   plod                  name                 title  male   culture  \
# 0     1  0.946  Viserys II Targaryen                   NaN     1       NaN
# 1     2  0.613           Walder Frey  Lord of the Crossing     1  Rivermen
# 2     3  0.507          Addison Hill                   Ser     1       NaN
# 3     4  0.924           Aemma Arryn                 Queen     0       NaN
# 4     5  0.383        Sylva Santagar            Greenstone     0   Dornish
#
#    dateOfBirth  DateoFdeath              mother            father  ...  \
# 0          NaN          NaN  Rhaenyra Targaryen  Daemon Targaryen  ...
# 1        208.0          NaN                 NaN               NaN  ...
# 2          NaN          NaN                 NaN               NaN  ...
# 3         82.0        105.0                 NaN               NaN  ...
# 4        276.0          NaN                 NaN               NaN  ...
#
#   isAliveHeir isAliveSpouse isMarried  isNoble   age  numDeadRelations  \
# ...

# %%
subset = ["attacker_king","defender_king","attacker_1","attacker_2","attacker_3","attacker_4","defender_1","defender_2","defender_3","defender_4","attacker_commander","defender_commander","note"]
battles_with_names = battles[subset].fillna("")
def in_battle(name, row):
    count = 0
    for i in range(len(battles)):
        if any(name in battles_with_names.iloc[row].iloc[i] for i in range(len(subset))):
            count+=1
    return count
battle_counts = characters['name'].apply(lambda x: in_battle(x, 0))

# %%
characters.loc[battle_counts > 0]
# Out:
#       S.No   plod              name       title  male      culture  \
# 5        6  0.979  Tommen Baratheon         NaN     1          NaN
# 95      96  0.295               Rob         NaN     1          NaN
# 101    102  0.964        Robb Stark         NaN     1          NaN
# 416    417  0.016           Clement     Brother     1          NaN
# 958    959  0.047     Clement Piper  Pinkmaiden     1     Rivermen
# 1741  1742  0.648   Jaime Lannister         Ser     1  Westerlands
#
#       dateOfBirth  DateoFdeath            mother            father  ...  \
# 5             NaN          NaN  Cersei Lannister  Robert Baratheon  ...
# 95            NaN          NaN               NaN               NaN  ...
# 101           NaN          NaN     Catelyn Stark      Eddard Stark  ...
# 416         251.0          NaN               NaN               NaN  ...
# 958           NaN          NaN               NaN               NaN  ...
# ...
